# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristianRavindu/ChristianRavindu/blob/main/Retail_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd # Data manipulation
import numpy as np # Numerical operations
import seaborn as sns # Statistical visualization
import matplotlib.pyplot as plt # Plotting
import warnings
warnings.filterwarnings("ignore") # Suppress warnings

# %%
# load data
data = pd.read_csv('/content/gdrive/MyDrive/DA/House Price/Retail_Cyber_Security_Dataset.csv')

# Preview data
data.head(11)
# Out:
#    Timestamp                        Transaction ID  \
# 0    01:47.5  32d3d0c1-fe44-4cb2-8c43-a232cf04648f
# 1    56:32.2  1cdd8017-320f-4911-95a0-6ea4bd41bfbb
# 2    43:28.8  c86c2a93-b5f7-45f8-ac6e-e48bb0dbbf2c
# 3    51:05.9  b6fac515-76d7-492a-a7fc-b253a6872701
# 4    45:19.6  267f34b4-5135-4aa2-a3d2-7308ea296c67
# 5    36:16.0  d6be880f-8d8e-4c49-8f8c-a6d59d908165
# 6    11:23.2  e7f1c028-08ce-4049-9245-1dbd9fa295ee
# 7    33:18.7  e5131026-d3a8-4bda-9f3f-2a44b1773a75
# 8    24:58.3  6a4e7e5e-8ff5-4124-8c39-a3f8f8f4bef5
# 9    57:34.4  d03dd11d-181a-405b-a0eb-f2a6c0244c2b
# 10   06:57.6  077c5ccc-e0b0-4dba-8093-0d9be68a9e54
#
#                              Customer ID  \
# 0   de745b60-1988-4479-a3e1-a512f8cce0a0
# 1   6407892a-608f-4d8d-b365-12afce2d5b4a
# 2   e417e111-b0d3-4bf2-a184-c47e98f5eeec
# 3   02a2eeae-f09b-4345-817d-4164e8cd8d65
# 4   34fd96b4-5a84-47b6-91b8-5375a12e10bb
# 5   d1f0c8a4-c62f-4594-9c04-42d9a5611e18
# 6   f8b4a12d-968e-4ff0-8e23-46824ace6210
# ...

# %%
# Display the first few rows of the dataset
print(data.head())
# Out:
#   Timestamp                        Transaction ID  \
# 0   01:47.5  32d3d0c1-fe44-4cb2-8c43-a232cf04648f
# 1   56:32.2  1cdd8017-320f-4911-95a0-6ea4bd41bfbb
# 2   43:28.8  c86c2a93-b5f7-45f8-ac6e-e48bb0dbbf2c
# 3   51:05.9  b6fac515-76d7-492a-a7fc-b253a6872701
# 4   45:19.6  267f34b4-5135-4aa2-a3d2-7308ea296c67
#
#                             Customer ID                            Product ID  \
# 0  de745b60-1988-4479-a3e1-a512f8cce0a0  ae7fe110-9a74-48b3-8c0d-6c272799853f
# 1  6407892a-608f-4d8d-b365-12afce2d5b4a  2f29dc27-4c45-4ed1-814d-7ce66cc6e556
# 2  e417e111-b0d3-4bf2-a184-c47e98f5eeec  59f94840-3d23-4373-bd7a-26a22cf748c4
# 3  02a2eeae-f09b-4345-817d-4164e8cd8d65  35a221f7-8166-4d53-ad7f-d64260ebd5be
# 4  34fd96b4-5a84-47b6-91b8-5375a12e10bb  f4fb3402-4dbe-404e-8c2e-ad8eef6b9543
#
#   Product Category  Amount Payment Method Transaction Status       IP Address  \
# 0          Apparel  301.38    Credit Card          Completed      97.239.8.82
# ...

# %%
# Basic statistics of numeric columns
print(data.describe())
# Out:
#             Amount  Session Duration
# count  1000.000000       1000.000000
# mean    517.641930       1836.100000
# std     283.902514       1025.058168
# min      10.130000         31.000000
# 25%     278.847500        964.500000
# 50%     511.680000       1825.500000
# 75%     766.525000       2759.000000
# max     999.670000       3598.000000

# %%
# Understanding the data types and checking for missing values
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Timestamp           1000 non-null   object
#  1   Transaction ID      1000 non-null   object
#  2   Customer ID         1000 non-null   object
#  3   Product ID          1000 non-null   object
#  4   Product Category    1000 non-null   object
#  5   Amount              1000 non-null   float64
#  6   Payment Method      1000 non-null   object
#  7   Transaction Status  1000 non-null   object
#  8   IP Address          1000 non-null   object
#  9   Location            1000 non-null   object
#  10  Device Type         1000 non-null   object
#  11  Session Duration    1000 non-null   int64
#  12  Anomaly Indicator   1000 non-null   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 101.7+ KB
# None

# %%
# Get the dimmensions of the DataFrame (rows, columns)
data.shape
# Out:
# (1000, 13)

# %%
data.columns
# Out:
# Index(['Timestamp', 'Transaction ID', 'Customer ID', 'Product ID',
#        'Product Category', 'Amount', 'Payment Method', 'Transaction Status',
#        'IP Address', 'Location', 'Device Type', 'Session Duration',
#        'Anomaly Indicator'],
#       dtype='object')

# %%
data.isna().sum() #check missing values
# Out:
# Timestamp             0
# Transaction ID        0
# Customer ID           0
# Product ID            0
# Product Category      0
# Amount                0
# Payment Method        0
# Transaction Status    0
# IP Address            0
# Location              0
# Device Type           0
# Session Duration      0
# Anomaly Indicator     0
# dtype: int64

# %%
data.nunique()
# Out:
# Timestamp              984
# Transaction ID        1000
# Customer ID           1000
# Product ID            1000
# Product Category         5
# Amount                 992
# Payment Method           4
# Transaction Status       3
# IP Address            1000
# Location                 5
# Device Type              3
# Session Duration       875
# Anomaly Indicator        2
# dtype: int64

# %%
# Check the data duplication
duplicates = data.duplicated()
print(f"Number of duplicate entries: {duplicates.sum()}")
# Out:
# Number of duplicate entries: 0

# %%
# Check for missing values in the dataset
missing_values = data.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Timestamp             0
# Transaction ID        0
# Customer ID           0
# Product ID            0
# Product Category      0
# Amount                0
# Payment Method        0
# Transaction Status    0
# IP Address            0
# Location              0
# Device Type           0
# Session Duration      0
# Anomaly Indicator     0
# dtype: int64

# %%
# Remove duplicates from the dataset
data_cleaned = data.drop_duplicates()
print(f"Number of duplicate entries removed: {duplicates.sum()}")
# Out:
# Number of duplicate entries removed: 0

# %%
data.describe()
# Out:
#             Amount  Session Duration
# count  1000.000000       1000.000000
# mean    517.641930       1836.100000
# std     283.902514       1025.058168
# min      10.130000         31.000000
# 25%     278.847500        964.500000
# 50%     511.680000       1825.500000
# 75%     766.525000       2759.000000
# max     999.670000       3598.000000

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Timestamp             0
# Transaction ID        0
# Customer ID           0
# Product ID            0
# Product Category      0
# Amount                0
# Payment Method        0
# Transaction Status    0
# IP Address            0
# Location              0
# Device Type           0
# Session Duration      0
# Anomaly Indicator     0
# dtype: int64

# %%
sns.pairplot(data)
plt.show()

# %%
plt.figure(figsize=(15,10))
# Convert string columns to numerical representation (if needed)
for col in data.columns:
    if data[col].dtype == 'object':  # Check if column is of object (string) type
        data[col] = pd.factorize(data[col])[0]  # Convert to numerical categories

sns.heatmap(data, annot=True)
plt.show()

# %%
sns.displot(data["Timestamp"])
plt.show()

# %%
# Import necessary library
import pandas as pd

# Load the Retail Cyber Security dataset (CSV file)
retail_cyber_df = pd.read_csv('/content/gdrive/MyDrive/DA/House Price/Retail_Cyber_Security_Dataset.csv')

# Confirm the dataset has been loaded correctly
print("First few rows of the Retail Cyber Security Dataset:")
print(retail_cyber_df.head())
# Out:
# First few rows of the Retail Cyber Security Dataset:
#   Timestamp                        Transaction ID  \
# 0   01:47.5  32d3d0c1-fe44-4cb2-8c43-a232cf04648f
# 1   56:32.2  1cdd8017-320f-4911-95a0-6ea4bd41bfbb
# 2   43:28.8  c86c2a93-b5f7-45f8-ac6e-e48bb0dbbf2c
# 3   51:05.9  b6fac515-76d7-492a-a7fc-b253a6872701
# 4   45:19.6  267f34b4-5135-4aa2-a3d2-7308ea296c67
#
#                             Customer ID                            Product ID  \
# 0  de745b60-1988-4479-a3e1-a512f8cce0a0  ae7fe110-9a74-48b3-8c0d-6c272799853f
# 1  6407892a-608f-4d8d-b365-12afce2d5b4a  2f29dc27-4c45-4ed1-814d-7ce66cc6e556
# 2  e417e111-b0d3-4bf2-a184-c47e98f5eeec  59f94840-3d23-4373-bd7a-26a22cf748c4
# 3  02a2eeae-f09b-4345-817d-4164e8cd8d65  35a221f7-8166-4d53-ad7f-d64260ebd5be
# 4  34fd96b4-5a84-47b6-91b8-5375a12e10bb  f4fb3402-4dbe-404e-8c2e-ad8eef6b9543
#
#   Product Category  Amount Payment Method Transaction Status       IP Address  \
# ...

# %%
# Display the column names to identify the binary categorical columns
print("Column names in the retail dataset:")
print(retail_cyber_df.columns)
# Out:
# Column names in the retail dataset:
# Index(['Timestamp', 'Transaction ID', 'Customer ID', 'Product ID',
#        'Product Category', 'Amount', 'Payment Method', 'Transaction Status',
#        'IP Address', 'Location', 'Device Type', 'Session Duration',
#        'Anomaly Indicator'],
#       dtype='object')

# %%
# Display the first few rows of the dataset to understand its structure
print("First few rows of the retail dataset:")
print(retail_cyber_df.head())

# Check the data types of each column to identify categorical and binary columns
print("\nColumn data types in the retail dataset:")
print(retail_cyber_df.dtypes)
# Out:
# First few rows of the retail dataset:
#   Timestamp                        Transaction ID  \
# 0   01:47.5  32d3d0c1-fe44-4cb2-8c43-a232cf04648f
# 1   56:32.2  1cdd8017-320f-4911-95a0-6ea4bd41bfbb
# 2   43:28.8  c86c2a93-b5f7-45f8-ac6e-e48bb0dbbf2c
# 3   51:05.9  b6fac515-76d7-492a-a7fc-b253a6872701
# 4   45:19.6  267f34b4-5135-4aa2-a3d2-7308ea296c67
#
#                             Customer ID                            Product ID  \
# 0  de745b60-1988-4479-a3e1-a512f8cce0a0  ae7fe110-9a74-48b3-8c0d-6c272799853f
# 1  6407892a-608f-4d8d-b365-12afce2d5b4a  2f29dc27-4c45-4ed1-814d-7ce66cc6e556
# 2  e417e111-b0d3-4bf2-a184-c47e98f5eeec  59f94840-3d23-4373-bd7a-26a22cf748c4
# 3  02a2eeae-f09b-4345-817d-4164e8cd8d65  35a221f7-8166-4d53-ad7f-d64260ebd5be
# 4  34fd96b4-5a84-47b6-91b8-5375a12e10bb  f4fb3402-4dbe-404e-8c2e-ad8eef6b9543
#
#   Product Category  Amount Payment Method Transaction Status       IP Address  \
# ...

# %%
# Display the column names and data types in the retail dataset
print("Column names and data types in the retail dataset:")
print(retail_cyber_df.columns)
print("\nData types of each column:")
print(retail_cyber_df.dtypes)
# Out:
# Column names and data types in the retail dataset:
# Index(['Timestamp', 'Transaction ID', 'Customer ID', 'Product ID',
#        'Product Category', 'Amount', 'Payment Method', 'Transaction Status',
#        'IP Address', 'Location', 'Device Type', 'Session Duration',
#        'Anomaly Indicator'],
#       dtype='object')
#
# Data types of each column:
# Timestamp              object
# Transaction ID         object
# Customer ID            object
# Product ID             object
# Product Category       object
# Amount                float64
# Payment Method         object
# Transaction Status     object
# IP Address             object
# Location               object
# Device Type            object
# Session Duration        int64
# Anomaly Indicator      object
# dtype: object

# %%
# Display all column names in the retail dataset
print("Column names in the retail dataset:")
print(retail_cyber_df.columns)
# Out:
# Column names in the retail dataset:
# Index(['Timestamp', 'Transaction ID', 'Customer ID', 'Product ID',
#        'Product Category', 'Amount', 'Payment Method', 'Transaction Status',
#        'IP Address', 'Location', 'Device Type', 'Session Duration',
#        'Anomaly Indicator'],
#       dtype='object')

# %%
# Check for any invalid or malformed entries in the Timestamp column
print(retail_data['Timestamp'].head(10))  # Print first 10 rows for inspection
# Out:
# 0    01:47.5
# 1    56:32.2
# 2    43:28.8
# 3    51:05.9
# 4    45:19.6
# 5    36:16.0
# 6    11:23.2
# 7    33:18.7
# 8    24:58.3
# 9    57:34.4
# Name: Timestamp, dtype: object

# %%
# Convert the 'Timestamp' column to datetime, using errors='coerce' to handle invalid formats
retail_data['Timestamp'] = pd.to_datetime(retail_data['Timestamp'], errors='coerce')

# Check for NaT (Not a Time) values that could not be converted
print(retail_data[retail_data['Timestamp'].isna()])  # Display rows with invalid timestamps

# Optionally, you can drop these rows if they are not needed
retail_data.dropna(subset=['Timestamp'], inplace=True)
# Out:
#     Timestamp                        Transaction ID  \
# 1         NaT  1cdd8017-320f-4911-95a0-6ea4bd41bfbb
# 2         NaT  c86c2a93-b5f7-45f8-ac6e-e48bb0dbbf2c
# 3         NaT  b6fac515-76d7-492a-a7fc-b253a6872701
# 4         NaT  267f34b4-5135-4aa2-a3d2-7308ea296c67
# 5         NaT  d6be880f-8d8e-4c49-8f8c-a6d59d908165
# ..        ...                                   ...
# 994       NaT  7dab867f-62a9-4446-89c0-33fba92b0950
# 995       NaT  8ca03374-bab1-4815-9939-3e78518b49ea
# 996       NaT  5cc1320b-7b48-4f1a-abb7-75d57fc44e47
# 997       NaT  08bdad25-542a-4213-90ed-4aad0bdbe077
# 998       NaT  1e16d1cf-92af-46e2-928a-5b8dd23fd6ac
#
#                               Customer ID  \
# 1    6407892a-608f-4d8d-b365-12afce2d5b4a
# 2    e417e111-b0d3-4bf2-a184-c47e98f5eeec
# 3    02a2eeae-f09b-4345-817d-4164e8cd8d65
# 4    34fd96b4-5a84-47b6-91b8-5375a12e10bb
# 5    d1f0c8a4-c62f-4594-9c04-42d9a5611e18
# ..                                    ...
# ...

# %%
# Convert 'Timestamp' to datetime and extract meaningful numeric features (e.g., hour, minute, day)
retail_data['Hour'] = retail_data['Timestamp'].dt.hour
retail_data['Day'] = retail_data['Timestamp'].dt.day
retail_data['Month'] = retail_data['Timestamp'].dt.month

# Drop the original 'Timestamp' column
retail_data.drop(columns=['Timestamp'], inplace=True)

# %%
# One-hot encoding for categorical columns
retail_data = pd.get_dummies(retail_data, columns=['Payment Method', 'Transaction Status', 'Device Type', 'Product Category', 'Location'], drop_first=True)

# %%
# Separate features (X) and target variable (y)
X_retail = retail_data.drop(columns=['Anomaly Indicator'])
y_retail = retail_data['Anomaly Indicator']

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets (80% training, 20% testing)
X_retail_train, X_retail_test, y_retail_train, y_retail_test = train_test_split(X_retail, y_retail, test_size=0.2, random_state=42)

# %%
# Print column names to verify the exact names
print(retail_data.columns)
# Out:
# Index(['Transaction ID', 'Customer ID', 'Product ID', 'Amount', 'IP Address',
#        'Session Duration', 'Anomaly Indicator', 'Hour', 'Day', 'Month',
#        'Payment Method_Credit Card', 'Payment Method_Debit Card',
#        'Payment Method_PayPal', 'Transaction Status_Failed',
#        'Transaction Status_Pending', 'Device Type_Mobile',
#        'Device Type_Tablet', 'Product Category_Electronics',
#        'Product Category_Furniture', 'Product Category_Groceries',
#        'Product Category_Toys', 'Location_Houston', 'Location_Los Angeles',
#        'Location_New York', 'Location_Phoenix'],
#       dtype='object')

# %%
# Strip any leading or trailing spaces from column names
retail_data.columns = retail_data.columns.str.strip()

# %%
# Drop the encoded 'Anomaly Indicator_Yes' column and use the rest as features
X_retail = retail_data_cleaned.drop(columns=['Anomaly Indicator_Yes'])
y_retail = retail_data_cleaned['Anomaly Indicator_Yes']

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_retail, y_retail, test_size=0.3, random_state=42)

# %%
from imblearn.over_sampling import SMOTE

# Initialize SMOTE
smote = SMOTE(sampling_strategy='auto', random_state=42)

# Apply SMOTE to the training data
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Check the distribution of the resampled data
print("Before SMOTE:")
print(y_train.value_counts())
print("\nAfter SMOTE:")
print(y_train_resampled.value_counts())
# Out:
# Before SMOTE:
# Anomaly Indicator_Yes
# False    143
# True     142
# Name: count, dtype: int64
#
# After SMOTE:
# Anomaly Indicator_Yes
# False    143
# True     143
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# Initialize the model (Random Forest)
model = RandomForestClassifier(random_state=42)

# Train the model on the resampled data
model.fit(X_train_resampled, y_train_resampled)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.4878048780487805
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.40      0.54      0.46        50
#         True       0.59      0.45      0.51        73
#
#     accuracy                           0.49       123
#    macro avg       0.50      0.50      0.49       123
# weighted avg       0.51      0.49      0.49       123

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Visualize the confusion matrix using a heatmap
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Fraud', 'Fraud'], yticklabels=['No Fraud', 'Fraud'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='blue', label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid for Random Forest
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=42), param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# %%
# Use the best model to predict
y_pred_best = best_model.predict(X_test)

# Evaluate the tuned model
print("Accuracy of Tuned Model:", accuracy_score(y_test, y_pred_best))
print("Classification Report of Tuned Model:")
print(classification_report(y_test, y_pred_best))
# Out:
# Accuracy of Tuned Model: 0.43902439024390244
# Classification Report of Tuned Model:
#               precision    recall  f1-score   support
#
#        False       0.36      0.48      0.41        50
#         True       0.54      0.41      0.47        73
#
#     accuracy                           0.44       123
#    macro avg       0.45      0.45      0.44       123
# weighted avg       0.46      0.44      0.44       123

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(model, X_retail, y_retail, cv=5)

# Display cross-validation scores
print(f"Cross-validation scores: {cv_scores}")
print(f"Average cross-validation score: {cv_scores.mean()}")
# Out:
# Cross-validation scores: [0.52439024 0.52439024 0.48780488 0.43209877 0.50617284]
# Average cross-validation score: 0.4949713941583861

# %%
import joblib

# Save the model to a file
joblib.dump(best_model, 'retail_fraud_detection_model.pkl')

# Load the model from the file
loaded_model = joblib.load('retail_fraud_detection_model.pkl')

# Make predictions with the loaded model
y_pred_loaded = loaded_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Visualize confusion matrix
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Non-Fraud', 'Fraud'], yticklabels=['Non-Fraud', 'Fraud'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Compute ROC curve
# Instead of y_pred_proba, use best_model.predict_proba(X_test)[:, 1] to get probabilities for the positive class
fpr, tpr, _ = roc_curve(y_test, best_model.predict_proba(X_test)[:, 1])
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# Calculate predicted probabilities for the positive class (assuming 'best_model' is your trained model)
y_pred_proba = best_model.predict_proba(X_test)[:, 1]

# Calculate Precision-Recall curve
precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)

# Plot Precision-Recall curve
plt.figure(figsize=(6,6))
plt.plot(recall, precision, color='b', lw=2)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming the model has a feature_importances_ attribute (e.g., RandomForest)
feature_importances = model.feature_importances_

# Sort features by importance
indices = np.argsort(feature_importances)[::-1]
features = X_retail.columns[indices]

# Plot feature importances
plt.figure(figsize=(10,6))
plt.barh(features, feature_importances[indices])
plt.xlabel('Feature Importance')
plt.title('Feature Importance')
plt.show()
